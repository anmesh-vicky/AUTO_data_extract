# %%
entries = mpr.query(criteria={"spacegroup.symbol": {"$in":["C2",
      "Cc",
      "Cm",
      "Cmm2",
      "Fmm2",
      "I4cm",
      "I4mm",
      "Iba2",
      "Ima2",
      "Imm2",
      "P1",
      "P2",
      "P4bm",
      "P4cc",
      "P4mm",
      "P4nc",
      "P6cc",
      "P6mm",
      "Pba2",
      "Pc",
      "Pm",
      "Pmm2",
      "Pnn2",
      "R3c",
      "R3m"]},"nelements":3},properties =["material_id","spacegroup.symbol"])
mp_ids = [e["material_id"] for e in entries]
len(mp_ids)

# %%
import pandas as pd
df = pd.DataFrame()
print("fetching")
for id in mp_ids:
    entries = mpr.query({"task_id":id},["cif","spacegroup.symbol"])
    df = df.append({"Space_group":entries[0]["spacegroup.symbol"],"Material_id":id},ignore_index=True)
    file = open("cif"+"/"+str(id)+".cif","w")
    file.write(entries[0]["cif"])
    file.close()
df.to_csv("data.csv")
print("fetched")

# %%
import json 
try:
    # Python 3
    from itertools import zip_longest
except ImportError:
    # Python 2
    from itertools import izip_longest as zip_longest

from tqdm import tqdm
from pymatgen import MPRester
mpr = MPRester("TZ4ibwqcz6vR2Kz2Wnt")

# %%
entries = mpr.query(criteria={"spacegroup.symbol": {"$in":["C2",
      "Cc",
      "Cm",
      "Cmm2",
      "Fmm2",
      "I4cm",
      "I4mm",
      "Iba2",
      "Ima2",
      "Imm2",
      "P1",
      "P2",
      "P4bm",
      "P4cc",
      "P4mm",
      "P4nc",
      "P6cc",
      "P6mm",
      "Pba2",
      "Pc",
      "Pm",
      "Pmm2",
      "Pnn2",
      "R3c",
      "R3m"]},"nelements":3},properties =["material_id","spacegroup"])
mp_ids = [e["material_id"] for e in entries]
len(mp_ids)

# %%
from pymatgen import MPRester                                                     
import urllib.request                                                             
import json                                                                       
                                                                                                                                       
MAPI_KEY = "TZ4ibwqcz6vR2Kz2Wn"  # You must change this to your Materials API key! (or set MAPI_KEY env variable)
                                                                                  
    # fetch list of a list of all available materials                             
with urllib.request.urlopen('https://www.materialsproject.org/rest/v1/materials//mids') as myurl:
    data = json.loads(myurl.read().decode())                                  
    material_ids = data['response'] # 75,000'ish material IDs are returned 
    
with MPRester(MAPI_KEY) as m: # object for connecting to MP Rest interface 
        criteria={'material_id': {'$in':material_ids[:4]}} # to avoid straining the servers, this is only using the first 4 materials
        properties=['energy', 'pretty_formula']            # list a few quanteties of interest
        data = m.query(criteria, properties)                                      
        print(data)

# %%
with MPRester(MAPI_KEY) as m: # object for connecting to MP Rest interface 
        criteria={'material_id': {'$in':material_ids[:4]}} # to avoid straining the servers, this is only using the first 4 materials
        properties=['energy', 'pretty_formula']            # list a few quanteties of interest
        data = m.query(criteria, properties)                                      
        print(data)

# %%
from pymatgen import MPRester
MAPI_KEY = "zwBEZLkvATrPMJ7y"
mpr = MPRester('zwBEZLkvATrPMJ7y')
data = mpr.query({'Spacegroup': {'$exists': True}}, ['material_id', 'Spacegroup'])

# %%
data

# %%
import pandas as pd
df = pd.DataFrame()
materials_id= pd.read_csv('data_id.csv', sep=',', engine='python',skipinitialspace = True, quotechar = '"',index_col=None, header=None)

# %%
mp_ids = pd.DataFrame()
mp_ids["id"]=materials_id.iloc[0]

# %%
test= mp_ids[964:1000]
test
# Out:
#              id
# 964  mp-1016217
# 965  mp-1016218
# 966  mp-1016219
# 967  mp-1016220
# 968  mp-1016221
# 969  mp-1016222
# 970  mp-1016223
# 971  mp-1016224
# 972  mp-1016225
# 973  mp-1016226
# 974  mp-1016227
# 975  mp-1016228
# 976  mp-1016229
# 977  mp-1016231
# 978  mp-1016233
# 979  mp-1016234
# 980  mp-1016235
# 981  mp-1016236
# 982  mp-1016237
# 983  mp-1016238
# 984  mp-1016239
# 985  mp-1016240
# 986  mp-1016241
# 987  mp-1016242
# 988  mp-1016243
# 989  mp-1016250
# 990  mp-1016252
# 991  mp-1016253
# 992  mp-1016254
# 993  mp-1016256
# 994  mp-1016257
# 995  mp-1016260
# 996  mp-1016262
# 997  mp-1016263
# 998  mp-1016264
# 999  mp-1016265

# %%
from pymatgen import MPRester

mpr = MPRester('zwBEZLkvATrPMJ7y')
df=pd.DataFrame()
print("fetching")
for id_ in mp_ids["id"]:
    try: 
         entries = mpr.query({"task_id":id_},["cif","spacegroup.symbol"])
         df = df.append({"Space_group":entries[0]["spacegroup.symbol"],"Material_id":id},ignore_index=True)
         file = open("cif"+"/"+str(id_)+".cif","w")
         file.write(entries[0]["cif"])
         file.close()
         print(id_)
         #print(entries)
    except:
        continue
df.to_csv("data_spacegroup.csv")
print("fetched")
# Out:
# fetching
# mp-1
# mp-10
# mp-100
# mp-1000
# mp-10000
# mp-10003
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\envs\crystal\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-26-d223d3d1b0a1> in <module>
#       5 print("fetching")
#       6 for id_ in mp_ids["id"]:
# ...

# %%
mp_ids[950:1000]
# Out:
#              id
# 950  mp-1016146
# 951  mp-1016152
# 952  mp-1016153
# 953  mp-1016154
# 954  mp-1016155
# 955  mp-1016165
# 956  mp-1016190
# 957  mp-1016197
# 958    mp-10162
# 959  mp-1016200
# 960  mp-1016212
# 961  mp-1016213
# 962  mp-1016214
# 963  mp-1016216
# 964  mp-1016217
# 965  mp-1016218
# 966  mp-1016219
# 967  mp-1016220
# 968  mp-1016221
# 969  mp-1016222
# 970  mp-1016223
# 971  mp-1016224
# 972  mp-1016225
# 973  mp-1016226
# 974  mp-1016227
# 975  mp-1016228
# 976  mp-1016229
# 977  mp-1016231
# 978  mp-1016233
# 979  mp-1016234
# 980  mp-1016235
# 981  mp-1016236
# 982  mp-1016237
# 983  mp-1016238
# 984  mp-1016239
# 985  mp-1016240
# 986  mp-1016241
# 987  mp-1016242
# 988  mp-1016243
# 989  mp-1016250
# 990  mp-1016252
# 991  mp-1016253
# 992  mp-1016254
# 993  mp-1016256
# 994  mp-1016257
# 995  mp-1016260
# 996  mp-1016262
# 997  mp-1016263
# 998  mp-1016264
# 999  mp-1016265

# %%
from pymatgen import MPRester

mpr = MPRester('zwBEZLkvATrPMJ7y')

docs = mpr.query({
    "has": "spacegroup.symbol",
}, [
    "material_id",
    "cif",
    "spacegroup",
])

# %%
docs

# %%
from pymatgen import MPRester

mpr = MPRester('zwBEZLkvATrPMJ7y')

docs = mpr.query({
    "has": "bandstructure",
}, [
    "material_id",
    "cif",
    "formation_energy_per_atom",
    "band_gap",
])

# %%
from pymatgen import MPRester

mpr = MPRester('zwBEZLkvATrPMJ7y')

docs = mpr.query({
    "has": "",
}, [
    "material_id",
    
])
